# %%
import pandas as pd 
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn import metrics

dataset = pd.read_csv("Second_week_first_dataset.csv", index_col = 'Unnamed: 0')

# %%
dataset
# Out:
#             X         Y
# 0    0.428854  0.003982
# 1   -0.020893 -0.294434
# 2   -0.797804 -0.700211
# 3    0.207282  0.252464
# 4   -0.259663  0.321410
# ..        ...       ...
# 995 -0.167543 -0.194640
# 996 -0.774930  0.682176
# 997 -0.001777  0.255835
# 998  0.336126  0.243974
# 999 -0.309893  0.254170
#
# [1000 rows x 2 columns]

# %%
plt.scatter(dataset['X'],dataset['Y'])

# %%
claster = AgglomerativeClustering(linkage='single').fit(dataset)

dataset["clast"]=claster.labels_

dataset
# Out:
#             X         Y  clast
# 0    0.428854  0.003982      1
# 1   -0.020893 -0.294434      1
# 2   -0.797804 -0.700211      0
# 3    0.207282  0.252464      1
# 4   -0.259663  0.321410      1
# ..        ...       ...    ...
# 995 -0.167543 -0.194640      1
# 996 -0.774930  0.682176      0
# 997 -0.001777  0.255835      1
# 998  0.336126  0.243974      1
# 999 -0.309893  0.254170      1
#
# [1000 rows x 3 columns]

# %%
colour_dict = {0:'dodgerblue',1:'limegreen'}

colours = [colour_dict[i] for i in dataset.clast]
plt.scatter(dataset.X, dataset.Y, c=colours)
